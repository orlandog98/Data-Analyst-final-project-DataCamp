# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# *Write your answer here*

# %% [markdown]
# The first task completed it was to see if the values describe the description in the table above.
# To check if the product_id was unique, it was needed to use the function unique and count if the values given below were everything. It was obtained 1500 different values, so the criteria was in order. In addition to see if there was not null values, it was needed to use the isnull function and sum, if the value is 0, then it means that there are not null values.
# ![2. 1.a.productid  ](2.%201.a.productid%20%20.png)
# For category, it was needed to check null values, again using the procedure than before it said that there was not null values, in addition it was used a code `for val in df_pet_category:
#     if (val != 'Housing') and (val != 'Food') and (val != 'Toys') and (val != 'Equipment') and (val != 'Medicine')  and (val != 'Accessory') and (val != 'Unknown'):
#         print(val)` to see if in the list the only categories were the mentioned before and also the missing values were replaced by unknown, however in this case the missing values were replaced by "-".
# ![3. 1.a.categories](3.%201.a.categories.png)
# For animal to check null values was used the function mentioned before, and for check the type of animals was used the next code `c=0
# for val in df_pet_animal:
#     if (val != 'Dog') and (val != 'Cat') and (val != 'Fish') and (val != 'Bird') and (val != 'Unknown'):
#         c=c+1
#         print(val)
# print(c)` To count the values in the list that are not Dog, Cat, etc or Unknown.
# ![4. 1.a.animal](4.%201.a.animal.png)
# To count null size it was used the funciton mentioned before of not null, and to see if the size only have the three values of Small, Medium and Large it was used the next code: `c=0
# wrong_values=[]
# for val in df_pet_size:
#     if (val != 'Small') and (val != 'Medium') and (val != 'Large') and (val != 'Unknown'):
#         c=c+1
#         wrong_values.append(val)
# print(c)
# print(wrong_values)` To see how many values are different that the mentioned before and see why are those values different.
# ![5. 1.a.size](5.%201.a.size.png)
# For price it was realized that the data was string, so it was easier to use regular expression to see if the numbers inserted are posivite, also to check that there are two numbers after decimal point. `import re
# c=0
# wrong_values=[]
# for val in df_pet_price:
#     n= re.match("^\d+\.\d\d$", val)
#     if not n:
#         c=c+1
#         wrong_values.append(val)
# print(c)
# print (wrong_values)
# `
# ![6. 1.a.price](6.%201.a.price.png)
# For sales the same method was applied, nevertheless the values were float, so at the beginning it was transformed the values to string and then applied the regular expression.
# `import re
# c=0
# wrong_values=[]
# for val in df_pet_sales:
#     val=str(val)
#     n= re.match("^\d+\.\d\d$", val)
#     if not n:
#         c=c+1
#         wrong_values.append(val)
# print(c)
# print (wrong_values)`
# ![7. 1.a.sales](7.%201.a.sales.png)
# For rating it was used if conditions to check if the number was bigger than 10 and less or equal than 1, and count the values that are beyond those limits.
# `c=0
# wrong_values=[]
# for val in df_pet_rating:
#     if (val >10) or (val < 0):
#         c=c+1
#         wrong_values.append(val)
# print(c)
# print (wrong_values)`
# ![8. 1.a.rating](8.%201.a.rating.png)
# Finally, for repeat_purchase it was used an if condition to see if the value is different to 0 and different to 1, the data with those requirements will be counted and if is bigger than 0 it means there will be wrong values added.
# `c=0
# wrong_values=[]
# for val in df_pet_repeat_purchase:
#     if (val !=0) and (val != 1):
#         c=c+1
#         wrong_values.append(val)
# print(c)
# print (wrong_values)`
# ![9 1.a.repeat](9%201.a.repeat.png)
#
# To check the missing values in all the columns was simple, in most of the cases were used the function `.isnull().sum()`
# As we can see in product id, animal, size, sales, rating and purchase.
# However in category it was used the code:
# `df_pet_category.value_counts()['-']` because the missing values were replaced by "-".
# The same happened with price, because the missing values were replaced by 'unlisted'
# `df_pet_price.value_counts()['unlisted']`
# It was obtained:
# 0 missing values in product_id
# 25 missing values in category
# 0 missing values in animal
# 0 missing values in size
# 150 missing values in price
# 0 missing values in sales
# 150 missing values in rating
# 0 missing values in repeat purchase
# ![10 1.b.1](10%201.b.1.png)
# ![11. 1.b.2](11.%201.b.2.png)
#
# *For step a and b it was easier to me to use a dataframe for each category (does not affect the result). In step c it was used the real dataframe imported for excel.
#
# Finally to replace and match the values for each category it was needed to use the replace function of dataframes.
#
# Product id was not needed to be replaced.
#
# In category it was used the replace function to replace the '-' to unknown.
# `df_pet['category'] = df_pet['category'].replace(['-'], 'Unknown')
# df_pet['category'].value_counts()['Unknown']`
#
# Animal was not needed to be replaced
#
# For size, it was noted that the size had different lower and upper letters, so the easiest way was to change all the data to lower letters and then replace the lower letter words to Large, Medium and Small.
# `df_pet['size']= df_pet['size'].str.lower()
# df_pet['size']=df_pet['size'].replace(['large','medium','small'],['Large','Medium','Small'])
# df_pet['size'].head()`
#
# For price the first thing was to replace the 'unlisted' with 0, then change the values from string to float, then obtain the median of all the values and finally replace the 0 values to the median obtained before. At the end all the values were rounded by 2.
# `df_pet['price']=df_pet['price'].replace('unlisted',0)
# df_pet['price']=df_pet['price'].astype(float)
# median=df_pet['price'].median()
# df_pet['price']=df_pet['price'].replace(0,median)
# df_pet['price'].round(2)`
#
# For sales, all the values were rounded by 2.
# `df_pet['sales'].round(2)`
#
# For rating it was used the function fillna to replace the null values to 0.
# `df_pet['rating'].fillna(value=0, inplace=True)
# df_pet['rating'].isnull().sum()`
#
# Repeat purchases was not needed to be replaced
# ![12. 1.ca](12.%201.ca.png)
# ![13. 1.c.2](13.%201.c.2.png)

# %% [markdown]
# ## Task 2

# %% [markdown]
# _Write your answer here_
#
# To visualize how many products are repeat purchases for each category it was necessary first to group the data for each category, and then sum all the repeat purchases values to obtain the category with most repeated purchases values.
#
# `import matplotlib as mp
# df_pet.groupby('category')['repeat_purchase'].sum().plot(kind='bar')
# mp.pyplot.show()`
# ![14. 2](14.%202.png)
#
# It was obtained the next bar chart
# ![foo](foo.png)
# As we can see from the bar chart, the equipment is the category that has the most repeated values, with 221. On the other hand we can see that the majority of the categories has almost the same repeated values. As we can see in the chart below.
#
# category
# Unknown       14
# Accessory     70
# Equipment    221
# Food         151
# Housing      152
# Medicine     153
# Toys         145

# %% [markdown]
# ## Task 3

# %% [markdown]
# _Write your answer here_
#
# To describe the distribution of all the sales was needed to use visualization.
# ![threea](threea.png)
# ![threea2](threea2.png)
#
# It was used two types of visualization, the first one was an histogram, and as we can see of the histogram is very close to a gaussian bell, with a mean of 996 and a standard deviation of 323.95. It is clear that there are some outliers in the graph. In addition, the graph is slightly skewed to the left, therefore the mean is less than the median (value= 1000.83)
#
# The next graph shows a pyplot, that help us with the idea that the data has some outliers. Also we can see in a better way the value of the median and the value of the 1st quartile (747.42) and the 3rd quartile (1158.16)

# %% [markdown]
# ## Task 4

# %% [markdown]
# _Write your answer here_
#
# Finally to see the relationship between repeat purchases and sales it was needed an ANOVA, because is the relation between a categorical variable and a continous variable.
# ![16. 4](16.%204.png)
#
# Obtaining a p value of 0.00207, because it is very small, we can reject the null hyphotesis and said that there is a correlation between the purchases and sales. As we can see in the graph below.
# ![four](four.png)
# ![four2](four2.png)
# Where the mean of the sales of the products with no repeated purchases is bigger 1028.36 compared to 975.76. As well as the median 1030.19 compared to 978.21. Showing that the change between not repeated purchases depends on the sales.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
